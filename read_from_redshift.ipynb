# %% [markdown]
# <a href="https://colab.research.google.com/github/JuanchoGithub/mejuri-data-challenge/blob/master/read_from_redshift.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import sqlalchemy as sa
from sqlalchemy.engine import url as sa_url

# %%
#THIS could be used instead: https://cloud.google.com/bigquery-transfer/docs/redshift-migration

jdbc_url = sa_url.URL(
            drivername='postgresql+psycopg2',
            username='mejuri_web',
            password='jFwJVh4e42nf',
            host='data-challenge.cvexhffiu36f.us-east-1.rds.amazonaws.com',
            port=5432,
            database='mejuri_web_prod',
)

engine = sa.create_engine(jdbc_url)
df = pd.read_sql_query('SELECT * FROM spree_orders LIMIT 10;', engine)
df
# Out:
#          id        number  item_total  ...  deleted_at coupon_code  subscribe
# 0  63135466  M113541806AP         0.0  ...        None        None       None
# 1  63135515   M90784284MO         0.0  ...        None        None       None
# 2  63135467   M88626573WQ         0.0  ...        None        None       None
# 3  63135468   M91373157HT         0.0  ...        None        None       None
# 4  63135516   M58122131AU         0.0  ...        None        None       None
# 5  63135469  M127806315JN         0.0  ...        None        None       None
# 6  63135470   M78301525SQ         0.0  ...        None        None       None
# 7  63135517  M268349634MO         0.0  ...        None        None       None
# 8  63135471  M136147181QC         0.0  ...        None        None       None
# 9  63135472   M71053917FE         0.0  ...        None        None       None
#
# [10 rows x 50 columns]
